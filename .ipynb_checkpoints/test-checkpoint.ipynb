# %%
import numpy as np
import pandas as pd

# %%
a = [1, 2, 7, 3, 4, 5]
print(np.max(a))
# Out:
# 7

# %%
import matplotlib.pyplot as plt

x = np.arange(1, 100, 1)
y = x**2

plt.plot(x, y)
plt.savefig(f'test_plot.png')
